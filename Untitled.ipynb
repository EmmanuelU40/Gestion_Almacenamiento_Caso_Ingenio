# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import urllib.parse
from sqlalchemy import create_engine, text
import mysql.connector
import os

# %%
csv_folder = "Data_Holder"
csv_folderlab = "data_sigind"

# %%
columnas = [
    "flujo_cond_klb_hr_time", "flujo_cond_klb_hr_value", "flujo_cana_ton_time", "flujo_cana_ton_value",
    "jcla_c1_m3_hr_time", "jcla_c1_m3_hr_value", "jcla_c2_m3_hr_time", "jcla_c2_m3_hr_value",
    "jcla_c3_m3_hr_time", "jcla_c3_m3_hr_value", "jcla_c4_m3_hr_time", "jcla_c4_m3_hr_value",
    "cond_c1_m3_hr_time", "cond_c1_m3_hr_value", "cond_c2_m3_hr_time", "cond_c2_m3_hr_value",
    "cond_c3_m3_hr_time", "cond_c3_m3_hr_value", "cond_c4_m3_hr_time", "cond_c4_m3_hr_value",
    "brix_mel_time", "brix_mel_value"
]

columnas2 = [
    "fecha_hora", "brix_jugo", "brix_melaza", "ph_alacalizado", "ph_clarificado", "ph_melada_sin_clarificador", "pza_jugo_clarificado", "pza_meladura_sin_clarificar"
]

# %%
def load_config(file_path="config.yaml"):
    with open(file_path, "r") as file:
        return yaml.safe_load(file)

# %%
config = load_config()
db_config = config["database"]

# %%
#Meter Credenciales
db_user = db_config["user"]
db_password = db_config["password"]
db_host = db_config["host"]
db_port = 3306 
db_name = db_config["name"]

# %%
print (db_name)
# Out:
# gestion

# %%
#Conectar a MySql
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password
)

# %%
#Crea un cursor para ejecutar consultas
cursor = conn.cursor()

# %%
#Crear la base de datos si no existe
cursor.execute(f"CREATE DATABASE IF NOT EXISTS {db_name}")

# %%
#Confirmar la creacion de la base de datos
print("Base de datos '{db_name}' creada o ya existía.")
# Out:
# Base de datos '{db_name}' creada o ya existía.

# %%
#Función para limpiar datos y subirlos a MySQL
def procesar_csv_y_subir(archivo_csv):
    print(f"Procesando: {archivo_csv}")
    
    try:
        # Leer el CSV
        df = pd.read_csv(archivo_csv, sep=";", engine="python")

        # 🔹 Renombrar columnas para mantener consistencia
        df.columns = columnas
        
        # 🔹 Insertar en MySQL
        with engine.connect() as conn:
            df.to_sql("gestion_table", con=engine, if_exists="append", index=False)

        print(f"{archivo_csv} cargado correctamente en MySQL.")

        #Borrar el archivo después de procesarlo
        os.remove(archivo_csv)
        print(f"Archivo eliminado: {archivo_csv}")

    except Exception as e:
        print(f"Error al procesar {archivo_csv}: {e}")

# %%
#Procesar y Subir  CSV de la Sigind
def procesar_csv_y_subir2(archivo_csv2):
    print(f"Procesando: {archivo_csv2}")
    
    try:
        # Leer el CSV
        # Leer desde la fila 8 (indexada como 7)
        df = pd.read_csv(archivo_csv2, sep=';', encoding='latin1')


        # 🔹 Renombrar columnas para mantener consistencia
        df.columns = columnas2
        
        # 🔹 Insertar en MySQL
        with engine.connect() as conn:
            df.to_sql("gestion_table_sigind", con=engine, if_exists="append", index=False)

        print(f"{archivo_csv2} sigind data cargada correctamente en MySQL.")

        #Borrar el archivo después de procesarlo
        os.remove(archivo_csv2)
        print(f"Archivo eliminado: {archivo_csv2}")

    except Exception as e:
        print(f"Error al procesar {archivo_csv2}: {e}")

# %%
#Conexion a la base de datos
try:
    conn = mysql.connector.connect(
        user=db_user, 
        password=db_password, 
        host=db_host, 
        database=db_name
    )
    cursor = conn.cursor()
    print(f"Conexión exitosa a la base de datos '{db_name}'.")

    cursor.close()
    conn.close()

except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Error de autenticación: Verifica tu usuario y contraseña.")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print(f"La base de datos '{db_name}' no existe.")
    else:
        print(f"Error: {err}")
# Out:
# Conexión exitosa a la base de datos 'gestion'.

# %%
#Configuracion a mi base de datos
db_config = {
    'host': db_host,  # Cambia según tu configuración
    'user': db_user,  # Coloca tu usuario de MySQL
    'password': db_password,  # Coloca tu contraseña de MySQL
    'database': db_name  # Nombre de la base de datos
}

# %%
#Conectar a la base de datos
try:
    connection = mysql.connector.connect(**db_config)
    cursor = connection.cursor()

    # Consulta SQL para crear la tabla
    create_table_query = """
    CREATE TABLE IF NOT EXISTS gestion_table (
        id INT AUTO_INCREMENT PRIMARY KEY,
        flujo_cond_klb_hr_time VARCHAR(30),
        flujo_cond_klb_hr_value VARCHAR(30),
        flujo_cana_ton_time VARCHAR(30),
        flujo_cana_ton_value VARCHAR(30),
        jcla_c1_m3_hr_time VARCHAR(30),
        jcla_c1_m3_hr_value VARCHAR(30),
        jcla_c2_m3_hr_time VARCHAR(30),
        jcla_c2_m3_hr_value VARCHAR(30),
        jcla_c3_m3_hr_time VARCHAR(30),
        jcla_c3_m3_hr_value VARCHAR(30),
        jcla_c4_m3_hr_time VARCHAR(30),
        jcla_c4_m3_hr_value VARCHAR(30),
        cond_c1_m3_hr_time VARCHAR(30),
        cond_c1_m3_hr_value VARCHAR(30),
        cond_c2_m3_hr_time VARCHAR(30),
        cond_c2_m3_hr_value VARCHAR(30),
        cond_c3_m3_hr_time VARCHAR(30),
        cond_c3_m3_hr_value VARCHAR(30),
        cond_c4_m3_hr_time VARCHAR(30),
        cond_c4_m3_hr_value VARCHAR(30),
        brix_mel_time VARCHAR(30),
        brix_mel_value VARCHAR(30)
    );
    """

    # Ejecutar la consulta
    cursor.execute(create_table_query)
    print("Tabla creada exitosamente.")

except mysql.connector.Error as error:
    print(f"Error al conectar o crear la tabla: {error}")
finally:
    # Cierra la conexión
    if connection.is_connected():
        cursor.close()
        connection.close()
# Out:
# Tabla creada exitosamente.

# %%
#Conectar a la base de datos
try:
    connection = mysql.connector.connect(**db_config)
    cursor = connection.cursor()

    # Consulta SQL para crear la tabla
    create_table_query = """
    CREATE TABLE IF NOT EXISTS gestion_table_sigind (
        id INT AUTO_INCREMENT PRIMARY KEY,
        fecha_hora VARCHAR(30), 
        brix_jugo VARCHAR(30), 
        brix_melaza VARCHAR(30), 
        ph_alacalizado VARCHAR(30), 
        ph_clarificado VARCHAR(30), 
        ph_melada_sin_clarificador VARCHAR(30), 
        pza_jugo_clarificado VARCHAR(30), 
        pza_meladura_sin_clarificar VARCHAR(30)
        
    );
    """

    # Ejecutar la consulta
    cursor.execute(create_table_query)
    print("Tabla creada exitosamente.")

except mysql.connector.Error as error:
    print(f"Error al conectar o crear la tabla: {error}")
finally:
    # Cierra la conexión
    if connection.is_connected():
        cursor.close()
        connection.close()
# Out:
# Tabla creada exitosamente.

# %%
#Codificar la contraseña 
encoded_password = urllib.parse.quote_plus(db_password)

connection_url = f"mysql+mysqlconnector://{db_user}:{encoded_password}@{db_host}/{db_name}"
print(connection_url)

#Crear modelo de conexion con SQLAlchemy
engine = create_engine(connection_url)
# Out:
# mysql+mysqlconnector://root:root@localhost/gestion

# %%
#Recorrer todos los archivos CSV en la carpeta y procesarlos
for archivo in os.listdir(csv_folder):
    if archivo.endswith(".csv"):
        procesar_csv_y_subir(os.path.join(csv_folder, archivo))

print("Todos los archivos CSV han sido procesados y eliminados.")
# Out:
# Procesando: Data_Holder\data07032025 T1(in).csv
# Data_Holder\data07032025 T1(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data07032025 T1(in).csv
# Procesando: Data_Holder\data07032025 T2(in).csv
# Data_Holder\data07032025 T2(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data07032025 T2(in).csv
# Procesando: Data_Holder\data07032025 T3(in).csv
# Data_Holder\data07032025 T3(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data07032025 T3(in).csv
# Procesando: Data_Holder\data08032025 T1(in).csv
# Data_Holder\data08032025 T1(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data08032025 T1(in).csv
# Procesando: Data_Holder\data08032025 T2(in).csv
# Data_Holder\data08032025 T2(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data08032025 T2(in).csv
# Procesando: Data_Holder\data08032025 T3(in).csv
# Data_Holder\data08032025 T3(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data08032025 T3(in).csv
# Procesando: Data_Holder\data09032025 T1(in).csv
# Data_Holder\data09032025 T1(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data09032025 T1(in).csv
# Procesando: Data_Holder\data09032025 T2(in).csv
# Data_Holder\data09032025 T2(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data09032025 T2(in).csv
# Procesando: Data_Holder\data09032025 T3(in).csv
# Error al procesar Data_Holder\data09032025 T3(in).csv: 'utf-8' codec can't decode byte 0xf1 in position 8: invalid continuation byte
# Procesando: Data_Holder\data10032025 T1(in).csv
# Data_Holder\data10032025 T1(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data10032025 T1(in).csv
# Procesando: Data_Holder\data10032025 T2(in).csv
# Data_Holder\data10032025 T2(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data10032025 T2(in).csv
# Procesando: Data_Holder\data10032025 T3(in).csv
# Data_Holder\data10032025 T3(in).csv cargado correctamente en MySQL.
# Archivo eliminado: Data_Holder\data10032025 T3(in).csv
# Todos los archivos CSV han sido procesados y eliminados.

# %%
#Recorrer todos los archivos CSV sigind en la carpeta y procesarlos
for archivo2 in os.listdir(csv_folderlab):
    if archivo2.endswith(".csv"):
        procesar_csv_y_subir2(os.path.join(csv_folderlab, archivo2))

print("Todos los archivos CSV sigind han sido procesados y eliminados.")
# Out:
# Procesando: data_sigind\Sigind marzo 10(Hoja2).csv
# data_sigind\Sigind marzo 10(Hoja2).csv sigind data cargada correctamente en MySQL.
# Archivo eliminado: data_sigind\Sigind marzo 10(Hoja2).csv
# Todos los archivos CSV sigind han sido procesados y eliminados.

# %% [markdown]
# # Transformacion

# %%
with engine.connect() as conn:
    db_extract_df1 = pd.read_sql("SELECT * FROM gestion_table", conn)

db_extract_df1.head(5)
# Out:
#    id flujo_cond_klb_hr_time flujo_cond_klb_hr_value flujo_cana_ton_time  \
# 0   1        03/07/2025 5:55             315,7195129     03/07/2025 5:55
# 1   2        03/07/2025 5:55             316,4519043     03/07/2025 5:55
# 2   3        03/07/2025 5:55             318,2991943     03/07/2025 5:55
# 3   4        03/07/2025 5:55             320,1952972     03/07/2025 5:55
# 4   5        03/07/2025 5:55             322,0832672     03/07/2025 5:55
#
#   flujo_cana_ton_value jcla_c1_m3_hr_time jcla_c1_m3_hr_value  \
# 0          443,7201843    03/07/2025 5:55         239,7504425
# 1          446,7375488    03/07/2025 5:55         240,2133942
# 2          433,6177368    03/07/2025 5:55         240,0976563
# 3          434,4269714    03/07/2025 5:55         240,1555176
# 4          448,7200928    03/07/2025 5:55         239,7504425
#
#   jcla_c2_m3_hr_time jcla_c2_m3_hr_value jcla_c3_m3_hr_time  ...  \
# 0    03/07/2025 5:55         234,9473267    03/07/2025 5:55  ...
# 1    03/07/2025 5:55         234,6001129    03/07/2025 5:55  ...
# 2    03/07/2025 5:55         234,4265137    03/07/2025 5:55  ...
# 3    03/07/2025 5:55         234,1950378    03/07/2025 5:55  ...
# 4    03/07/2025 5:55         234,7158508    03/07/2025 5:55  ...
#
#   cond_c1_m3_hr_time cond_c1_m3_hr_value cond_c2_m3_hr_time  \
# 0    03/07/2025 5:55         77,64546204    03/07/2025 5:55
# 1    03/07/2025 5:55         78,40499115    03/07/2025 5:55
# 2    03/07/2025 5:55         79,92404175    03/07/2025 5:55
# 3    03/07/2025 5:55         79,18621826    03/07/2025 5:55
# 4    03/07/2025 5:55         75,99620056    03/07/2025 5:55
#
#   cond_c2_m3_hr_value cond_c3_m3_hr_time cond_c3_m3_hr_value  \
# 0          86,3908844    03/07/2025 5:55            2,17E-02
# 1         79,68533325    03/07/2025 5:55            2,17E-02
# 2         82,07242584    03/07/2025 5:55            2,17E-02
# 3         84,06889343    03/07/2025 5:55            2,17E-02
# 4         86,04367065    03/07/2025 5:55            2,17E-02
#
#   cond_c4_m3_hr_time cond_c4_m3_hr_value    brix_mel_time brix_mel_value
# 0    03/07/2025 5:55         8,984130859  03/07/2025 5:55    63,73738098
# 1    03/07/2025 5:55         8,875626564  03/07/2025 5:55    63,64052963
# 2    03/07/2025 5:55         8,745422363  03/07/2025 5:55    63,57015228
# 3    03/07/2025 5:55         8,398209572  03/07/2025 5:55    63,54139709
# 4    03/07/2025 5:55         8,094398499  03/07/2025 5:55    63,50404358
#
# [5 rows x 23 columns]

# %%
with engine.connect() as conn:
    db_extract_df2 = pd.read_sql("SELECT * FROM gestion_table_sigind", conn)

db_extract_df2.head(5)
# Out:
#    id          fecha_hora brix_jugo brix_melaza ph_alacalizado ph_clarificado  \
# 0   1  01/03/sábado 06:30      None      59,000           7,89           7,32
# 1   2  01/03/sábado 08:30      None      59,160           7,58           None
# 2   3  01/03/sábado 10:30      None      58,720           7,46           6,88
# 3   4  01/03/sábado 12:30    11,600      60,440           7,47           6,88
# 4   5  01/03/sábado 14:30      None      60,200           7,43           6,80
#
#   ph_melada_sin_clarificador pza_jugo_clarificado pza_meladura_sin_clarificar
# 0                       6,42                 None                        None
# 1                       6,34                 None                      84,843
# 2                       6,20                 None                        None
# 3                       6,17               85,293                      85,903
# 4                       6,15                 None                        None

# %%
db_extract_df1.isna().sum()
# Out:
# id                              0
# flujo_cond_klb_hr_time     158396
# flujo_cond_klb_hr_value    158396
# flujo_cana_ton_time             0
# flujo_cana_ton_value            0
# jcla_c1_m3_hr_time         158396
# jcla_c1_m3_hr_value        158396
# jcla_c2_m3_hr_time         158396
# jcla_c2_m3_hr_value        158396
# jcla_c3_m3_hr_time         158396
# jcla_c3_m3_hr_value        158396
# jcla_c4_m3_hr_time         158396
# jcla_c4_m3_hr_value        158396
# cond_c1_m3_hr_time         158396
# cond_c1_m3_hr_value        158396
# cond_c2_m3_hr_time         158396
# cond_c2_m3_hr_value        158396
# cond_c3_m3_hr_time         158396
# cond_c3_m3_hr_value        158396
# cond_c4_m3_hr_time         158396
# cond_c4_m3_hr_value        158396
# brix_mel_time              253434
# brix_mel_value             253434
# dtype: int64

# %%
db_extract_df1 = db_extract_df1[db_extract_df1.iloc[:, 1].notna()]
db_extract_df1["brix_mel_time"] = db_extract_df1["brix_mel_time"].fillna(0)
db_extract_df1["brix_mel_value"] = db_extract_df1["brix_mel_value"].fillna(0)

# %%
db_extract_df1.isna().sum()
# Out:
# id                         0
# flujo_cond_klb_hr_time     0
# flujo_cond_klb_hr_value    0
# flujo_cana_ton_time        0
# flujo_cana_ton_value       0
# jcla_c1_m3_hr_time         0
# jcla_c1_m3_hr_value        0
# jcla_c2_m3_hr_time         0
# jcla_c2_m3_hr_value        0
# jcla_c3_m3_hr_time         0
# jcla_c3_m3_hr_value        0
# jcla_c4_m3_hr_time         0
# jcla_c4_m3_hr_value        0
# cond_c1_m3_hr_time         0
# cond_c1_m3_hr_value        0
# cond_c2_m3_hr_time         0
# cond_c2_m3_hr_value        0
# cond_c3_m3_hr_time         0
# cond_c3_m3_hr_value        0
# cond_c4_m3_hr_time         0
# cond_c4_m3_hr_value        0
# brix_mel_time              0
# brix_mel_value             0
# dtype: int64

# %%
db_extract_df1
# Out:
#             id flujo_cond_klb_hr_time flujo_cond_klb_hr_value  \
# 0            1        03/07/2025 5:55             315,7195129
# 1            2        03/07/2025 5:55             316,4519043
# 2            3        03/07/2025 5:55             318,2991943
# 3            4        03/07/2025 5:55             320,1952972
# 4            5        03/07/2025 5:55             322,0832672
# ...        ...                    ...                     ...
# 302388  302389        03/11/2025 5:58             370,8612366
# 302389  302390        03/11/2025 5:58             370,8612366
# 302390  302391        03/11/2025 5:58             372,0168152
# 302391  302392        03/11/2025 5:58             368,1920471
# 302392  302393        03/11/2025 5:59             367,2724609
#
#        flujo_cana_ton_time flujo_cana_ton_value jcla_c1_m3_hr_time  \
# 0                 2,17E-02    03/07/2025 5:55         8,984130859
# 1                 2,17E-02    03/07/2025 5:55         8,875626564
# 2                 2,17E-02    03/07/2025 5:55         8,745422363
# 3                 2,17E-02    03/07/2025 5:55         8,398209572
# 4                 2,17E-02    03/07/2025 5:55         8,094398499
# ...                    ...                ...                 ...
# 302388         77,62375641    03/11/2025 5:58         88,19204712
# 302389         77,81906891    03/11/2025 5:58          86,4125824
# 302390         77,53695679    03/11/2025 5:58          86,3908844
# 302391         78,10118103    03/11/2025 5:58         83,11405945
# 302392          77,8624649    03/11/2025 5:59         79,72873688
#
#           brix_mel_time brix_mel_value
# 0       03/07/2025 5:55    63,73738098
# 1       03/07/2025 5:55    63,64052963
# 2       03/07/2025 5:55    63,57015228
# 3       03/07/2025 5:55    63,54139709
# 4       03/07/2025 5:55    63,50404358
# ...                 ...            ...
# 302388                0              0
# 302389                0              0
# 302390                0              0
# 302391                0              0
# 302392                0              0
#
# [158397 rows x 23 columns]

# %%
# Convertir todos los None en NaN reales
db_extract_df2 = db_extract_df2.replace(to_replace=[None], value=np.nan)

# Ahora sí, imputar la mediana correctamente
db_extract_df2 = db_extract_df2.fillna(db_extract_df2.median(numeric_only=True))

# %%
#Detectar columnas numéricas excepto 'id' y 'fecha_hora'
columnas_numericas = db_extract_df2.columns.difference(["id", "fecha_hora"])

#Reemplazar comas por puntos y convertir a numérico
for col in columnas_numericas:
    db_extract_df2[col] = db_extract_df2[col].astype(str).str.replace(",", ".")
    db_extract_df2[col] = pd.to_numeric(db_extract_df2[col], errors="coerce")

#imputar la mediana en columnas numéricas
db_extract_df2 = db_extract_df2.fillna(db_extract_df2.median(numeric_only=True))

# %%
# Asegurar que la columna sea string
db_extract_df2["fecha_hora_str"] = db_extract_df2["fecha_hora"].astype(str)

# Extraer los 6 primeros y los 5 últimos caracteres
db_extract_df2["fecha_inicio"] = db_extract_df2["fecha_hora_str"].str[:6]
db_extract_df2["hora_fin"] = db_extract_df2["fecha_hora_str"].str[-5:]

# %%
db_extract_df2
# Out:
#       id          fecha_hora  brix_jugo  brix_melaza  ph_alacalizado  \
# 0      1  01/03/sábado 06:30      11.75        59.00            7.89
# 1      2  01/03/sábado 08:30      11.75        59.16            7.58
# 2      3  01/03/sábado 10:30      11.75        58.72            7.46
# 3      4  01/03/sábado 12:30      11.60        60.44            7.47
# 4      5  01/03/sábado 14:30      11.75        60.20            7.43
# ..   ...                 ...        ...          ...             ...
# 122  123  11/03/martes 20:30      11.75        59.32            7.63
# 123  124  11/03/martes 22:30      11.75        63.60            7.24
# 124  125  11/03/martes 00:30      11.75        63.24            7.50
# 125  126  11/03/martes 02:30      11.75        60.72            7.58
# 126  127  11/03/martes 04:30      10.93        60.80            7.46
#
#      ph_clarificado  ph_melada_sin_clarificador  pza_jugo_clarificado  \
# 0              7.32                        6.42                84.920
# 1              7.22                        6.34                84.920
# 2              6.88                        6.20                84.920
# 3              6.88                        6.17                85.293
# 4              6.80                        6.15                84.920
# ..              ...                         ...                   ...
# 122            7.22                        6.49                85.123
# 123            6.94                        6.50                84.920
# 124            7.22                        6.36                84.920
# 125            6.92                        6.28                84.920
# 126            7.22                        6.26                86.093
#
#      pza_meladura_sin_clarificar      fecha_hora_str fecha_inicio hora_fin
# 0                         86.449  01/03/sábado 06:30       01/03/    06:30
# 1                         84.843  01/03/sábado 08:30       01/03/    08:30
# 2                         86.449  01/03/sábado 10:30       01/03/    10:30
# 3                         85.903  01/03/sábado 12:30       01/03/    12:30
# 4                         86.449  01/03/sábado 14:30       01/03/    14:30
# ..                           ...                 ...          ...      ...
# 122                       86.074  11/03/martes 20:30       11/03/    20:30
# 123                       86.449  11/03/martes 22:30       11/03/    22:30
# 124                       86.885  11/03/martes 00:30       11/03/    00:30
# 125                       86.449  11/03/martes 02:30       11/03/    02:30
# 126                       86.701  11/03/martes 04:30       11/03/    04:30
#
# [127 rows x 12 columns]

# %%
db_extract_df2["fecha_hora_compuesta"] = db_extract_df2["fecha_inicio"] + "2025 " + db_extract_df2["hora_fin"]

# %%
db_extract_df2
# Out:
#       id          fecha_hora  brix_jugo  brix_melaza  ph_alacalizado  \
# 0      1  01/03/sábado 06:30      11.75        59.00            7.89
# 1      2  01/03/sábado 08:30      11.75        59.16            7.58
# 2      3  01/03/sábado 10:30      11.75        58.72            7.46
# 3      4  01/03/sábado 12:30      11.60        60.44            7.47
# 4      5  01/03/sábado 14:30      11.75        60.20            7.43
# ..   ...                 ...        ...          ...             ...
# 122  123  11/03/martes 20:30      11.75        59.32            7.63
# 123  124  11/03/martes 22:30      11.75        63.60            7.24
# 124  125  11/03/martes 00:30      11.75        63.24            7.50
# 125  126  11/03/martes 02:30      11.75        60.72            7.58
# 126  127  11/03/martes 04:30      10.93        60.80            7.46
#
#      ph_clarificado  ph_melada_sin_clarificador  pza_jugo_clarificado  \
# 0              7.32                        6.42                84.920
# 1              7.22                        6.34                84.920
# 2              6.88                        6.20                84.920
# 3              6.88                        6.17                85.293
# 4              6.80                        6.15                84.920
# ..              ...                         ...                   ...
# 122            7.22                        6.49                85.123
# 123            6.94                        6.50                84.920
# 124            7.22                        6.36                84.920
# 125            6.92                        6.28                84.920
# 126            7.22                        6.26                86.093
#
#      pza_meladura_sin_clarificar      fecha_hora_str fecha_inicio hora_fin  \
# 0                         86.449  01/03/sábado 06:30       01/03/    06:30
# 1                         84.843  01/03/sábado 08:30       01/03/    08:30
# 2                         86.449  01/03/sábado 10:30       01/03/    10:30
# 3                         85.903  01/03/sábado 12:30       01/03/    12:30
# 4                         86.449  01/03/sábado 14:30       01/03/    14:30
# ..                           ...                 ...          ...      ...
# 122                       86.074  11/03/martes 20:30       11/03/    20:30
# 123                       86.449  11/03/martes 22:30       11/03/    22:30
# 124                       86.885  11/03/martes 00:30       11/03/    00:30
# 125                       86.449  11/03/martes 02:30       11/03/    02:30
# 126                       86.701  11/03/martes 04:30       11/03/    04:30
#
#     fecha_hora_compuesta
# 0       01/03/2025 06:30
# 1       01/03/2025 08:30
# 2       01/03/2025 10:30
# 3       01/03/2025 12:30
# 4       01/03/2025 14:30
# ..                   ...
# 122     11/03/2025 20:30
# 123     11/03/2025 22:30
# 124     11/03/2025 00:30
# 125     11/03/2025 02:30
# 126     11/03/2025 04:30
#
# [127 rows x 13 columns]

# %%
db_extract_df2["fecha_hora_compuesta"] = pd.to_datetime(
    db_extract_df2["fecha_hora_compuesta"], format="%d/%m/%Y %H:%M", errors="coerce"
)

# %%
db_extract_df2
# Out:
#       id          fecha_hora  brix_jugo  brix_melaza  ph_alacalizado  \
# 0      1  01/03/sábado 06:30      11.75        59.00            7.89
# 1      2  01/03/sábado 08:30      11.75        59.16            7.58
# 2      3  01/03/sábado 10:30      11.75        58.72            7.46
# 3      4  01/03/sábado 12:30      11.60        60.44            7.47
# 4      5  01/03/sábado 14:30      11.75        60.20            7.43
# ..   ...                 ...        ...          ...             ...
# 122  123  11/03/martes 20:30      11.75        59.32            7.63
# 123  124  11/03/martes 22:30      11.75        63.60            7.24
# 124  125  11/03/martes 00:30      11.75        63.24            7.50
# 125  126  11/03/martes 02:30      11.75        60.72            7.58
# 126  127  11/03/martes 04:30      10.93        60.80            7.46
#
#      ph_clarificado  ph_melada_sin_clarificador  pza_jugo_clarificado  \
# 0              7.32                        6.42                84.920
# 1              7.22                        6.34                84.920
# 2              6.88                        6.20                84.920
# 3              6.88                        6.17                85.293
# 4              6.80                        6.15                84.920
# ..              ...                         ...                   ...
# 122            7.22                        6.49                85.123
# 123            6.94                        6.50                84.920
# 124            7.22                        6.36                84.920
# 125            6.92                        6.28                84.920
# 126            7.22                        6.26                86.093
#
#      pza_meladura_sin_clarificar      fecha_hora_str fecha_inicio hora_fin  \
# 0                         86.449  01/03/sábado 06:30       01/03/    06:30
# 1                         84.843  01/03/sábado 08:30       01/03/    08:30
# 2                         86.449  01/03/sábado 10:30       01/03/    10:30
# 3                         85.903  01/03/sábado 12:30       01/03/    12:30
# 4                         86.449  01/03/sábado 14:30       01/03/    14:30
# ..                           ...                 ...          ...      ...
# 122                       86.074  11/03/martes 20:30       11/03/    20:30
# 123                       86.449  11/03/martes 22:30       11/03/    22:30
# 124                       86.885  11/03/martes 00:30       11/03/    00:30
# 125                       86.449  11/03/martes 02:30       11/03/    02:30
# 126                       86.701  11/03/martes 04:30       11/03/    04:30
#
#     fecha_hora_compuesta
# 0    2025-03-01 06:30:00
# 1    2025-03-01 08:30:00
# 2    2025-03-01 10:30:00
# 3    2025-03-01 12:30:00
# 4    2025-03-01 14:30:00
# ..                   ...
# 122  2025-03-11 20:30:00
# 123  2025-03-11 22:30:00
# 124  2025-03-11 00:30:00
# 125  2025-03-11 02:30:00
# 126  2025-03-11 04:30:00
#
# [127 rows x 13 columns]

# %%
db_extract_df2.drop(columns=["fecha_hora", "fecha_hora_str", "fecha_inicio", "hora_fin"], inplace=True)
# Reordenar columnas: poner fecha_hora_compuesta en segundo lugar
cols = db_extract_df2.columns.tolist()
# Sacar la columna si ya está en la lista (por si está en otro lugar)
cols.remove("fecha_hora_compuesta")
# Insertarla en la segunda posición
cols.insert(1, "fecha_hora_compuesta")
# Reordenar el DataFrame
db_extract_df2 = db_extract_df2[cols]

# %%
db_extract_df2
# Out:
#       id fecha_hora_compuesta  brix_jugo  brix_melaza  ph_alacalizado  \
# 0      1  2025-03-01 06:30:00      11.75        59.00            7.89
# 1      2  2025-03-01 08:30:00      11.75        59.16            7.58
# 2      3  2025-03-01 10:30:00      11.75        58.72            7.46
# 3      4  2025-03-01 12:30:00      11.60        60.44            7.47
# 4      5  2025-03-01 14:30:00      11.75        60.20            7.43
# ..   ...                  ...        ...          ...             ...
# 122  123  2025-03-11 20:30:00      11.75        59.32            7.63
# 123  124  2025-03-11 22:30:00      11.75        63.60            7.24
# 124  125  2025-03-11 00:30:00      11.75        63.24            7.50
# 125  126  2025-03-11 02:30:00      11.75        60.72            7.58
# 126  127  2025-03-11 04:30:00      10.93        60.80            7.46
#
#      ph_clarificado  ph_melada_sin_clarificador  pza_jugo_clarificado  \
# 0              7.32                        6.42                84.920
# 1              7.22                        6.34                84.920
# 2              6.88                        6.20                84.920
# 3              6.88                        6.17                85.293
# 4              6.80                        6.15                84.920
# ..              ...                         ...                   ...
# 122            7.22                        6.49                85.123
# 123            6.94                        6.50                84.920
# 124            7.22                        6.36                84.920
# 125            6.92                        6.28                84.920
# 126            7.22                        6.26                86.093
#
#      pza_meladura_sin_clarificar
# 0                         86.449
# 1                         84.843
# 2                         86.449
# 3                         85.903
# 4                         86.449
# ..                           ...
# 122                       86.074
# 123                       86.449
# 124                       86.885
# 125                       86.449
# 126                       86.701
#
# [127 rows x 9 columns]

# %%
columnas_fecha = [
    "flujo_cond_klb_hr_time",
    "flujo_cana_ton_time",
    "jcla_c1_m3_hr_time",
    "jcla_c2_m3_hr_time",
    "jcla_c3_m3_hr_time",
    "jcla_c4_m3_hr_time",
    "cond_c1_m3_hr_time",
    "cond_c2_m3_hr_time",
    "cond_c3_m3_hr_time",
    "cond_c4_m3_hr_time",
    "brix_mel_time"
]

# %%
db_extract_df1.head(5)
# Out:
#    id flujo_cond_klb_hr_time flujo_cond_klb_hr_value flujo_cana_ton_time  \
# 0   1        03/07/2025 5:55             315,7195129     03/07/2025 5:55
# 1   2        03/07/2025 5:55             316,4519043     03/07/2025 5:55
# 2   3        03/07/2025 5:55             318,2991943     03/07/2025 5:55
# 3   4        03/07/2025 5:55             320,1952972     03/07/2025 5:55
# 4   5        03/07/2025 5:55             322,0832672     03/07/2025 5:55
#
#   flujo_cana_ton_value jcla_c1_m3_hr_time jcla_c1_m3_hr_value  \
# 0          443,7201843    03/07/2025 5:55         239,7504425
# 1          446,7375488    03/07/2025 5:55         240,2133942
# 2          433,6177368    03/07/2025 5:55         240,0976563
# 3          434,4269714    03/07/2025 5:55         240,1555176
# 4          448,7200928    03/07/2025 5:55         239,7504425
#
#   jcla_c2_m3_hr_time jcla_c2_m3_hr_value jcla_c3_m3_hr_time  ...  \
# 0    03/07/2025 5:55         234,9473267    03/07/2025 5:55  ...
# 1    03/07/2025 5:55         234,6001129    03/07/2025 5:55  ...
# 2    03/07/2025 5:55         234,4265137    03/07/2025 5:55  ...
# 3    03/07/2025 5:55         234,1950378    03/07/2025 5:55  ...
# 4    03/07/2025 5:55         234,7158508    03/07/2025 5:55  ...
#
#   cond_c1_m3_hr_time cond_c1_m3_hr_value cond_c2_m3_hr_time  \
# 0    03/07/2025 5:55         77,64546204    03/07/2025 5:55
# 1    03/07/2025 5:55         78,40499115    03/07/2025 5:55
# 2    03/07/2025 5:55         79,92404175    03/07/2025 5:55
# 3    03/07/2025 5:55         79,18621826    03/07/2025 5:55
# 4    03/07/2025 5:55         75,99620056    03/07/2025 5:55
#
#   cond_c2_m3_hr_value cond_c3_m3_hr_time cond_c3_m3_hr_value  \
# 0          86,3908844    03/07/2025 5:55            2,17E-02
# 1         79,68533325    03/07/2025 5:55            2,17E-02
# 2         82,07242584    03/07/2025 5:55            2,17E-02
# 3         84,06889343    03/07/2025 5:55            2,17E-02
# 4         86,04367065    03/07/2025 5:55            2,17E-02
#
#   cond_c4_m3_hr_time cond_c4_m3_hr_value    brix_mel_time brix_mel_value
# 0    03/07/2025 5:55         8,984130859  03/07/2025 5:55    63,73738098
# 1    03/07/2025 5:55         8,875626564  03/07/2025 5:55    63,64052963
# 2    03/07/2025 5:55         8,745422363  03/07/2025 5:55    63,57015228
# 3    03/07/2025 5:55         8,398209572  03/07/2025 5:55    63,54139709
# 4    03/07/2025 5:55         8,094398499  03/07/2025 5:55    63,50404358
#
# [5 rows x 23 columns]

# %%
columnas_numericas1 = db_extract_df1.columns.difference(["id","flujo_cond_klb_hr_time",
    "flujo_cana_ton_time",
    "jcla_c1_m3_hr_time",
    "jcla_c2_m3_hr_time",
    "jcla_c3_m3_hr_time",
    "jcla_c4_m3_hr_time",
    "cond_c1_m3_hr_time",
    "cond_c2_m3_hr_time",
    "cond_c3_m3_hr_time",
    "cond_c4_m3_hr_time",
    "brix_mel_time"])

#Reemplazar comas por puntos y a numerico
for col in columnas_numericas1:
    db_extract_df1[col] = db_extract_df1[col].astype(str).str.replace(",", ".")
    db_extract_df1[col] = pd.to_numeric(db_extract_df1[col], errors="coerce")

# %%
db_extract_df1
# Out:
#             id flujo_cond_klb_hr_time  flujo_cond_klb_hr_value  \
# 0            1        03/07/2025 5:55               315.719513
# 1            2        03/07/2025 5:55               316.451904
# 2            3        03/07/2025 5:55               318.299194
# 3            4        03/07/2025 5:55               320.195297
# 4            5        03/07/2025 5:55               322.083267
# ...        ...                    ...                      ...
# 302388  302389        03/11/2025 5:58               370.861237
# 302389  302390        03/11/2025 5:58               370.861237
# 302390  302391        03/11/2025 5:58               372.016815
# 302391  302392        03/11/2025 5:58               368.192047
# 302392  302393        03/11/2025 5:59               367.272461
#
#        flujo_cana_ton_time  flujo_cana_ton_value jcla_c1_m3_hr_time  \
# 0          03/07/2025 5:55            443.720184    03/07/2025 5:55
# 2                 0.021700     03/07/2025 5:55            8.745422
# 3                 0.021700     03/07/2025 5:55            8.398210
# 4                 0.021700     03/07/2025 5:55            8.094398
# ...                    ...                 ...                 ...
# 302388           77.623756     03/11/2025 5:58           88.192047
# 302389           77.819069     03/11/2025 5:58           86.412582
# 302390           77.536957     03/11/2025 5:58           86.390884
# 302391           78.101181     03/11/2025 5:58           83.114059
# 302392           77.862465     03/11/2025 5:59           79.728737
#
#           brix_mel_time brix_mel_value
# 0       03/07/2025 5:55      63.737381
# 1       03/07/2025 5:55      63.640530
# 2       03/07/2025 5:55      63.570152
# 3       03/07/2025 5:55      63.541397
# 4       03/07/2025 5:55      63.504044
# ...                 ...            ...
# 302388                0       0.000000
# 302389                0       0.000000
# 302390                0       0.000000
# 302391                0       0.000000
# 302392                0       0.000000
#
# [158397 rows x 23 columns]

# %%
db_extract_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158397 entries, 0 to 302392
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       158397 non-null  int64
#  1   flujo_cond_klb_hr_time   158397 non-null  object
#  2   flujo_cond_klb_hr_value  158397 non-null  float64
#  3   flujo_cana_ton_time      158397 non-null  object
#  4   flujo_cana_ton_value     158397 non-null  float64
#  5   jcla_c1_m3_hr_time       158397 non-null  object
#  6   jcla_c1_m3_hr_value      158397 non-null  float64
#  7   jcla_c2_m3_hr_time       158397 non-null  object
#  8   jcla_c2_m3_hr_value      158397 non-null  float64
#  9   jcla_c3_m3_hr_time       158397 non-null  object
#  10  jcla_c3_m3_hr_value      158397 non-null  float64
#  11  jcla_c4_m3_hr_time       158397 non-null  object
#  12  jcla_c4_m3_hr_value      158397 non-null  float64
#  13  cond_c1_m3_hr_time       158397 non-null  object
#  14  cond_c1_m3_hr_value      158397 non-null  float64
#  15  cond_c2_m3_hr_time       158397 non-null  object
#  16  cond_c2_m3_hr_value      158397 non-null  float64
#  17  cond_c3_m3_hr_time       158397 non-null  object
#  18  cond_c3_m3_hr_value      158397 non-null  float64
#  19  cond_c4_m3_hr_time       158397 non-null  object
#  20  cond_c4_m3_hr_value      158397 non-null  float64
#  21  brix_mel_time            158397 non-null  object
#  22  brix_mel_value           158397 non-null  float64
# dtypes: float64(11), int64(1), object(11)
# memory usage: 29.0+ MB

# %%
# Calcular el Indicador 1
db_extract_df1["indicador_1"] = (
    db_extract_df1["flujo_cond_klb_hr_value"] * 1000
) / db_extract_df1["flujo_cana_ton_value"]

# Crear nueva tabla con el tiempo y el indicador
indicador_1_df = db_extract_df1[[
    "flujo_cond_klb_hr_time", "indicador_1"
]].copy()

# Renombrar columna de tiempo si querés más claridad
indicador_1_df.rename(columns={
    "flujo_cond_klb_hr_time": "tiempo",
    "indicador_1": "Indicador 1"
}, inplace=True)

# %%
indicador_1_df
# Out:
#                  tiempo  Indicador 1
# 0       03/07/2025 5:55   711.528400
# 1       03/07/2025 5:55   708.362002
# 2       03/07/2025 5:55   734.054831
# 3       03/07/2025 5:55   737.052067
# 4       03/07/2025 5:55   717.782137
# ...                 ...          ...
# 302388  03/11/2025 5:58   769.425014
# 302389  03/11/2025 5:58   763.392878
# 302390  03/11/2025 5:58   762.047229
# 302391  03/11/2025 5:58   759.764090
# 302392  03/11/2025 5:59   763.177493
#
# [158397 rows x 2 columns]

# %%
# Asegurar que la columna 'tiempo' es datetime
indicador_1_df['tiempo'] = pd.to_datetime(indicador_1_df['tiempo'])

# Obtener la primera fecha en los datos y ajustar a las 06:30
inicio = indicador_1_df['tiempo'].min().replace(hour=6, minute=30, second=0, microsecond=0)

# Generar los intervalos de 2 horas desde el primer dato sin reiniciar cada día
indicador_1_df['intervalo'] = inicio + ((indicador_1_df['tiempo'] - inicio) // pd.Timedelta(hours=2)) * pd.Timedelta(hours=2)

# Detectar y eliminar valores atípicos usando el rango intercuartílico (IQR)
Q1 = indicador_1_df['Indicador 1'].quantile(0.25)
Q3 = indicador_1_df['Indicador 1'].quantile(0.75)
IQR = Q3 - Q1

# Definir límites para detectar valores atípicos
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar los valores dentro del rango permitido
indicador_1_df_filtrado = indicador_1_df[(indicador_1_df['Indicador 1'] >= limite_inferior) & (indicador_1_df['Indicador 1'] <= limite_superior)]

# Agrupar por el intervalo de 2 horas y calcular la media sin valores atípicos
indicador_1_df_agrupado = indicador_1_df_filtrado.groupby('intervalo', as_index=False)['Indicador 1'].mean()

# Renombrar la columna "intervalo" a "tiempo"
indicador_1_df_agrupado = indicador_1_df_agrupado.rename(columns={'intervalo': 'tiempo'})

# Mostrar los primeros resultados
print(indicador_1_df_agrupado.head())
# Out:
#                tiempo  Indicador 1
# 0 2025-03-07 04:30:00   723.384029
# 1 2025-03-07 06:30:00   721.749675
# 2 2025-03-07 08:30:00   755.734474
# 3 2025-03-07 10:30:00   800.148176
# 4 2025-03-07 12:30:00   760.017135

# %%
indicador_1_df_agrupado
# Out:
#                 tiempo  Indicador 1
# 0  2025-03-07 04:30:00   723.384029
# 1  2025-03-07 06:30:00   721.749675
# 2  2025-03-07 08:30:00   755.734474
# 3  2025-03-07 10:30:00   800.148176
# 4  2025-03-07 12:30:00   760.017135
# 5  2025-03-07 14:30:00   751.264721
# 6  2025-03-07 16:30:00   762.169556
# 7  2025-03-07 18:30:00   769.216522
# 8  2025-03-07 20:30:00   818.913787
# 9  2025-03-07 22:30:00   898.402828
# 10 2025-03-08 00:30:00   910.594123
# 11 2025-03-08 02:30:00   887.829743
# 12 2025-03-08 04:30:00   869.169689
# 13 2025-03-08 06:30:00   800.362202
# 14 2025-03-08 08:30:00   877.651568
# 15 2025-03-08 10:30:00   897.347361
# 16 2025-03-08 12:30:00   878.672670
# 17 2025-03-08 14:30:00   907.985091
# 18 2025-03-08 16:30:00   922.040714
# 19 2025-03-08 18:30:00   937.895957
# 20 2025-03-08 20:30:00   867.713863
# 21 2025-03-08 22:30:00   814.045552
# 22 2025-03-09 00:30:00   804.237479
# 23 2025-03-09 02:30:00   768.663434
# 24 2025-03-09 04:30:00   770.860235
# 25 2025-03-09 06:30:00   764.095459
# 26 2025-03-09 08:30:00   728.035294
# 27 2025-03-09 10:30:00   748.800807
# 2         03/07/2025 5:55  ...            79.924042    03/07/2025 5:55
# 3         03/07/2025 5:55  ...            79.186218    03/07/2025 5:55
# 4         03/07/2025 5:55  ...            75.996201    03/07/2025 5:55
# ...                   ...  ...                  ...                ...
# 302388    03/11/2025 5:58  ...             0.043400    03/11/2025 5:58
# 302389    03/11/2025 5:58  ...             0.043400    03/11/2025 5:58
# 302390    03/11/2025 5:58  ...             0.043400    03/11/2025 5:58
# 302391    03/11/2025 5:58  ...             0.043400    03/11/2025 5:58
# 302392    03/11/2025 5:59  ...             0.043400    03/11/2025 5:59
#
#         cond_c2_m3_hr_value cond_c3_m3_hr_time  cond_c3_m3_hr_value  \
# 0                 86.390884    03/07/2025 5:55             0.021700
# 1                 79.685333    03/07/2025 5:55             0.021700
# 2                 82.072426    03/07/2025 5:55             0.021700
# 3                 84.068893    03/07/2025 5:55             0.021700
# 4                 86.043671    03/07/2025 5:55             0.021700
# ...                     ...                ...                  ...
# 302388            65.840225    03/11/2025 5:58            77.623756
# 302389            64.407974    03/11/2025 5:58            77.819069
# 302390            65.080696    03/11/2025 5:58            77.536957
# 302391            66.209137    03/11/2025 5:58            78.101181
# 302392            65.623215    03/11/2025 5:59            77.862465
#
#        cond_c4_m3_hr_time  cond_c4_m3_hr_value    brix_mel_time  \
# 0         03/07/2025 5:55             8.984131  03/07/2025 5:55
# 1         03/07/2025 5:55             8.875627  03/07/2025 5:55
# 2         03/07/2025 5:55             8.745422  03/07/2025 5:55
# 3         03/07/2025 5:55             8.398210  03/07/2025 5:55
# 4         03/07/2025 5:55             8.094398  03/07/2025 5:55
# ...                   ...                  ...              ...
# 302388    03/11/2025 5:58            88.192047                0
# 302389    03/11/2025 5:58            86.412582                0
# 302390    03/11/2025 5:58            86.390884                0
# 302391    03/11/2025 5:58            83.114059                0
# 302392    03/11/2025 5:59            79.728737                0
#
#         brix_mel_value indicador_1
# 0            63.737381  711.528400
# 1            63.640530  708.362002
# 2            63.570152  734.054831
# 3            63.541397  737.052067
# 4            63.504044  717.782137
# ...                ...         ...
# 302388        0.000000  769.425014
# 302389        0.000000  763.392878
# 302390        0.000000  762.047229
# 302391        0.000000  759.764090
# 302392        0.000000  763.177493
#
# [158397 rows x 24 columns]

# %%
# Lista para guardar todos los DataFrames preparados
lista_dfs = []

# Identificar columnas de tiempo
columnas_time = [col for col in db_extract_df1.columns if col.endswith('_time')]

for col_time in columnas_time:
    col_valor = col_time.replace('_time', '_value')

    if col_valor not in db_extract_df1.columns:
        continue

    # Trabajar con sub-DataFrame
    df_temp = db_extract_df1[[col_time, col_valor]].dropna().copy()

    # Reemplazar valores no válidos con NaT antes de convertir
    df_temp[col_time] = pd.to_datetime(df_temp[col_time], errors='coerce')

    # Verificar si hay valores NaT antes de proceder
    if df_temp[col_time].isna().sum() > 0:
        print(f"Existen valores NaT en la columna {col_time}, serán ignorados.")

    # Crear intervalos
    inicio = df_temp[col_time].min().replace(hour=6, minute=30, second=0, microsecond=0)
    df_temp['fecha_hora'] = inicio + ((df_temp[col_time] - inicio) // pd.Timedelta(hours=2)) * pd.Timedelta(hours=2)

    # Filtrar outliers
    Q1 = df_temp[col_valor].quantile(0.25)
    Q3 = df_temp[col_valor].quantile(0.75)
    IQR = Q3 - Q1
    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR
    df_filtrado = df_temp[(df_temp[col_valor] >= lim_inf) & (df_temp[col_valor] <= lim_sup)]

    # Agrupar y renombrar
    df_agrupado = df_filtrado.groupby('fecha_hora', as_index=False)[col_valor].mean()
    lista_dfs.append(df_agrupado)

# Combinar todos los DataFrames por 'fecha_hora'
df_merged = reduce(lambda left, right: pd.merge(left, right, on='fecha_hora', how='outer'), lista_dfs)

# Ordenar por fecha
df_merged = df_merged.sort_values(by='fecha_hora')

# Mostrar
print(df_merged.head())
# Out:
# Existen valores NaT en la columna brix_mel_time, serán ignorados.
#            fecha_hora  flujo_cond_klb_hr_value  flujo_cana_ton_value  \
# 0 2025-03-07 04:30:00               309.596598            427.328418
# 1 2025-03-07 06:30:00               310.314723            422.850255
# 2 2025-03-07 08:30:00               319.326492            417.781663
# 3 2025-03-07 10:30:00               325.767482                   NaN
# 4 2025-03-07 12:30:00               322.684140            413.574549
#
#    jcla_c1_m3_hr_value  jcla_c2_m3_hr_value  jcla_c3_m3_hr_value  \
# 0           241.883928           239.141939             0.117336
# 1           263.937142           260.948709             0.116573
# 2           267.737933           257.422048             0.116365
# 3           264.769006           258.214384             0.116975
# 4           254.422981           248.097739             0.117124
#
#    jcla_c4_m3_hr_value  cond_c1_m3_hr_value  cond_c2_m3_hr_value  \
# 0             0.115738            77.744023            85.666212
# 1             0.115738            75.743874            85.630908
# 2             0.115738            77.491035            88.018974
# 3             0.115738            79.615712            90.388812
# 4             0.115738            78.759711            90.240493
#
#    cond_c3_m3_hr_value  cond_c4_m3_hr_value  brix_mel_value
# 0             0.019633             6.862888       66.978067
# 1             0.020989             4.969797       62.691097
# 2             0.211799             7.047920       64.797380
# 3             0.080347             2.570551       63.557917
# 4             0.000720             2.863007       62.346327

# %%
df_merged
# Out:
#             fecha_hora  flujo_cond_klb_hr_value  flujo_cana_ton_value  \
# 0  2025-03-07 04:30:00               309.596598            427.328418
# 1  2025-03-07 06:30:00               310.314723            422.850255
# 2  2025-03-07 08:30:00               319.326492            417.781663
# 3  2025-03-07 10:30:00               325.767482                   NaN
# 4  2025-03-07 12:30:00               322.684140            413.574549
# 5  2025-03-07 14:30:00               314.526904            421.264863
# 6  2025-03-07 16:30:00               319.616425            408.806687
# 7  2025-03-07 18:30:00               325.104019                   NaN
# 8  2025-03-07 20:30:00               324.637251            369.741560
# 9  2025-03-07 22:30:00               308.985914            342.510737
# 10 2025-03-08 00:30:00               317.825994            357.276250
# 11 2025-03-08 02:30:00               317.108005                   NaN
# 12 2025-03-08 04:30:00               309.772834            336.629416
# 13 2025-03-08 06:30:00               304.723862            346.238032
# 14 2025-03-08 08:30:00               306.841935            352.741552
# 16            90.555562             0.848943       63.753647
# 17            92.058957            -0.000036       66.870981
# 18            93.739250             8.944931       66.481336
# 19            92.564085            16.173099       65.320132
# 20            91.707965            -0.000060       64.979635
# 21            90.737884            -0.000036       63.141917
# 22            92.241677            -0.000054       63.372265
# 23            90.961288            -0.000078       65.706875
# 24            92.357587            -0.000091       64.110419
# 25            92.375143            -0.000060       54.781352
# 26            93.417939            -0.000090       56.294245
# 27            94.108917            -0.000084       66.228104
# 28            95.257676            -0.000030       65.005274
# 29            93.810205             0.299574       63.960593
# 30            93.762246            -0.000030       64.566511
# 31            78.064973            51.617563       62.985941
# 32            71.656858            74.667751       63.897410
# 33            69.660182            83.691381       63.744029
# 34            71.487202            82.888500       62.781187
# 35            70.413874            83.532122       61.665867
# 36            68.595377            79.505472       61.920360
# 37            71.428082            81.919339       59.711849
# 38            72.302718            83.555764       60.532313
# 39            73.032546            84.955519       53.869525
# 40            73.675974            85.532333       64.791879
# 41            75.015244            84.421830       65.816769
# 42            74.923831            84.478222       66.062293
# 43            73.765050            77.964119       67.341567
# 44            75.228009            75.966705       66.862653
# 45            74.820636            83.820731       64.689068

# %%
db_extract_df2.loc[:, "Indicador 2"] = (
    (db_extract_df2["brix_melaza"] - db_extract_df2["brix_jugo"]) / db_extract_df2["brix_melaza"]
) * 100
# Crear tabla nueva
indicador_2_df = db_extract_df2[["fecha_hora_compuesta", "Indicador 2"]].copy()
indicador_2_df.rename(columns={"fecha_hora_compuesta": "tiempo"}, inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7932\573990931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_extract_df2.loc[:, "Indicador 2"] = (

# %%
indicador_2_df
# Out:
#                  tiempo  Indicador 2
# 0   2025-03-01 06:30:00    80.084746
# 1   2025-03-01 08:30:00    80.138607
# 2   2025-03-01 10:30:00    79.989782
# 3   2025-03-01 12:30:00    80.807412
# 4   2025-03-01 14:30:00    80.481728
# ..                  ...          ...
# 122 2025-03-11 20:30:00    80.192178
# 123 2025-03-11 22:30:00    81.525157
# 124 2025-03-11 00:30:00    81.419987
# 125 2025-03-11 02:30:00    80.648880
# 126 2025-03-11 04:30:00    82.023026
#
# [127 rows x 2 columns]

# %%
# Renombrar la columna 'tiempo' a 'fecha_hora' en indicador_2_df
indicador_2_df = indicador_2_df.rename(columns={"tiempo": "fecha_hora"})
indicador_1_df_agrupado = indicador_1_df_agrupado.rename(columns={"tiempo": "fecha_hora"})


# Convertir 'fecha_hora' en indicador_2_df a tipo datetime
indicador_2_df["fecha_hora"] = pd.to_datetime(indicador_2_df["fecha_hora"])

# Realizar el merge
df_merged = df_merged.merge(indicador_1_df_agrupado, on="fecha_hora", how="left")
df_merged = df_merged.merge(indicador_2_df, on="fecha_hora", how="left")

# %%
df_merged = df_merged.rename(columns={
    "Indicador 2": "Indicador_2",
    "Indicador 1": "Indicador_1"
})
print(df_merged.columns)
# Out:
# Index(['fecha_hora', 'flujo_cond_klb_hr_value', 'flujo_cana_ton_value',
#        'jcla_c1_m3_hr_value', 'jcla_c2_m3_hr_value', 'jcla_c3_m3_hr_value',
#        'jcla_c4_m3_hr_value', 'cond_c1_m3_hr_value', 'cond_c2_m3_hr_value',
#        'cond_c3_m3_hr_value', 'cond_c4_m3_hr_value', 'brix_mel_value',
#        'Indicador_1', 'Indicador_2'],
#       dtype='object')

# %%
# --- 1. CREAR TABLA DE DIMENSIÓN TIEMPO SI NO EXISTE ---
with engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS dim_fecha (
            Id_Fecha DATETIME PRIMARY KEY,
            Ano INT,
            Mes INT,
            Dia INT,
            Hora TIME
        );
    """))

# --- 2. CREAR TABLA DE HECHOS CON NUEVA LLAVE PRIMARIA ---
with engine.begin() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS hechos_indicadores (
            id_hecho INT AUTO_INCREMENT PRIMARY KEY,
            Id_Fecha DATETIME,
            flujo_cond_klb_hr_value FLOAT,
            flujo_cana_ton_value FLOAT,
            brix_mel_value FLOAT,
            Indicador_1 FLOAT,
            Indicador_2 FLOAT,
            FOREIGN KEY (Id_Fecha) REFERENCES dim_fecha(Id_Fecha)
        );
    """))
# --- 3. CREAR DIMENSIÓN TIEMPO DESDE LOS DATOS ---
dim_fecha_df = pd.DataFrame()
dim_fecha_df["Id_Fecha"] = df_merged["fecha_hora"]  # O "Id_Fecha", según tu DataFrame
dim_fecha_df["Ano"] = dim_fecha_df["Id_Fecha"].dt.year
dim_fecha_df["Mes"] = dim_fecha_df["Id_Fecha"].dt.month
dim_fecha_df["Dia"] = dim_fecha_df["Id_Fecha"].dt.day
dim_fecha_df["Hora"] = dim_fecha_df["Id_Fecha"].dt.time

dim_fecha_df = dim_fecha_df.drop_duplicates()

hechos_df = df_merged[[
    "fecha_hora",
    "flujo_cond_klb_hr_value",
    "flujo_cana_ton_value",
    "brix_mel_value",
    "Indicador_1",
    "Indicador_2"
]].rename(columns={"fecha_hora": "Id_Fecha"})

# --- 5. EVITAR DUPLICADOS EN INSERCIÓN ---
fechas_cargadas = pd.read_sql("SELECT Id_Fecha FROM dim_fecha", con=engine)
dim_fecha_nueva = dim_fecha_df[~dim_fecha_df["Id_Fecha"].isin(fechas_cargadas["Id_Fecha"])]
hechos_nuevos = hechos_df[~hechos_df["Id_Fecha"].isin(fechas_cargadas["Id_Fecha"])]

# --- 6. INSERTAR DATOS EN LA BASE ---
dim_fecha_nueva.to_sql("dim_fecha", con=engine, if_exists="append", index=False)
hechos_nuevos.to_sql("hechos_indicadores", con=engine, if_exists="append", index=False)

print("Dimensión tiempo y tabla de hechos cargadas exitosamente en MySQL.")
# Out:
# Dimensión tiempo y tabla de hechos cargadas exitosamente en MySQL.

# %%
hechos_nuevos = hechos_nuevos.rename(columns={
    "Indicador 1": "Flujo_Condensados",
    "Indicador 2": "Brix_Eficiencia"
})

# %%
indicador_1_df_agrupado = indicador_1_df_agrupado.rename(columns={"tiempo": "Id_Fecha", "Indicador 1": "Indicador_1"})
indicador_2_df = indicador_2_df.rename(columns={"tiempo": "Id_Fecha", "Indicador 2": "Indicador_2"})

# %%
dim_fecha_df = pd.DataFrame()
dim_fecha_df["Id_Fecha"] = hechos_df["Id_Fecha"]
dim_fecha_df["Ano"] = dim_fecha_df["Id_Fecha"].dt.year
dim_fecha_df["Mes"] = dim_fecha_df["Id_Fecha"].dt.month
dim_fecha_df["Dia"] = dim_fecha_df["Id_Fecha"].dt.day
dim_fecha_df["Hora"] = dim_fecha_df["Id_Fecha"].dt.time
dim_fecha_df = dim_fecha_df.drop_duplicates()

# %%
# Ver qué fechas ya existen
fechas_cargadas = pd.read_sql("SELECT Id_Fecha FROM dim_fecha", con=engine)

# Filtrar las nuevas
dim_fecha_nueva = dim_fecha_df[~dim_fecha_df["Id_Fecha"].isin(fechas_cargadas["Id_Fecha"])]
hechos_nuevos = hechos_df[~hechos_df["Id_Fecha"].isin(fechas_cargadas["Id_Fecha"])]

# %%
hechos_df.to_sql("hechos_indicadores", con=engine, if_exists="append", index=False)
# Out:
# 46

# %%
from sqlalchemy.exc import IntegrityError

try:
    dim_fecha_nueva.to_sql("dim_fecha", con=engine, if_exists="append", index=False)
except IntegrityError as e:
    print("Saltando duplicados en dim_fecha:", e)

hechos_nuevos.to_sql("hechos_indicadores", con=engine, if_exists="append", index=False)
# Out:
# 0

# %%
print("Total en hechos_df:", len(hechos_df))
print("Total ya cargadas:", len(fechas_cargadas))
print("Total nuevas a insertar:", len(hechos_nuevos))
# Out:
# Total en hechos_df: 46
# Total ya cargadas: 46
# Total nuevas a insertar: 0

# %%
# Eliminar datos antiguos
with engine.begin() as conn:
    conn.execute(text("DELETE FROM hechos_indicadores"))

# Insertar todos los datos nuevos
hechos_df.to_sql("hechos_indicadores", con=engine, if_exists="append", index=False)
# Out:
# 46

# %%
df_merged.to_csv("df_merged.csv", index=False)
hechos_df.to_csv("hechos_df.csv", index=False)

# %%
print(hechos_df.head(10))
print(hechos_df.isnull().sum())
# Out:
#              Id_Fecha  flujo_cond_klb_hr_value  flujo_cana_ton_value  \
# 0 2025-03-07 04:30:00               309.596598            427.328418
# 1 2025-03-07 06:30:00               310.314723            422.850255
# 2 2025-03-07 08:30:00               319.326492            417.781663
# 3 2025-03-07 10:30:00               325.767482                   NaN
# 4 2025-03-07 12:30:00               322.684140            413.574549
# 5 2025-03-07 14:30:00               314.526904            421.264863
# 6 2025-03-07 16:30:00               319.616425            408.806687
# 7 2025-03-07 18:30:00               325.104019                   NaN
# 8 2025-03-07 20:30:00               324.637251            369.741560
# 9 2025-03-07 22:30:00               308.985914            342.510737
#
#    brix_mel_value  Indicador_1  Indicador_2
# 0       66.978067   723.384029    81.684923
# 1       62.691097   721.749675    83.868753
# 2       64.797380   755.734474    83.271640
# 3       63.557917   800.148176    84.283039
# 4       62.346327   760.017135    83.039709
# 5       64.137603   751.264721    83.552632
# 6       64.350213   762.169556    82.525283
# 7       63.909535   769.216522    83.175830
# 8       59.892985   818.913787    82.859238
# 9       65.427988   898.402828    81.978528
# Id_Fecha                    0
# flujo_cond_klb_hr_value     0
# flujo_cana_ton_value       13
# brix_mel_value              0
# Indicador_1                 0
# Indicador_2                 0
# dtype: int64
